# %%
# Importing necessary libraries
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
import matplotlib.pyplot as plt
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
import seaborn as sns
from sklearn.metrics import accuracy_score

# %%
# Importing dataset
data = pd.read_csv("D:\\Users\\Jeewanshu Gaur\\Downloads\\final dataset.csv")
data.head()
# Out:
#         Revenue  Cost of Revenue  Gross Profit  R&D Expenses  SG&A Expense  \
# 0  6.505800e+10     3.263800e+10  3.242000e+10           0.0  1.865400e+10
# 1  1.102060e+10     8.557810e+09  2.462794e+09   273345223.7  8.201852e+08
# 2  1.150000e+11     8.950200e+10  2.583500e+10           0.0  1.916200e+10
# 3  2.292754e+10     1.786283e+10  5.064707e+09           0.0  4.776995e+09
# 4  1.561980e+10     1.005200e+10  5.567800e+09           0.0  2.888800e+09
#
#    Operating Expenses  Interest Expense  Income Tax Expense    Net Income  \
# 0        1.865400e+10      4.650000e+08        3.063000e+09  1.532600e+10
# 1        2.056136e+09      1.245995e+07        9.464027e+07  2.946879e+08
# 2        2.238300e+10      5.220000e+08        9.570000e+08  1.975000e+09
# 3        4.816124e+09      2.000650e+08        4.443800e+07  4.053000e+06
# 4        3.069200e+09      2.951000e+08        6.552000e+08  1.657500e+09
#
# ...

# %%
data.shape
# Out:
# (4960, 50)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4960 entries, 0 to 4959
# Data columns (total 50 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Revenue                          4435 non-null   float64
#  1   Cost of Revenue                  4281 non-null   float64
#  2   Gross Profit                     4426 non-null   float64
#  3   R&D Expenses                     4173 non-null   float64
#  4   SG&A Expense                     4299 non-null   float64
#  5   Operating Expenses               4299 non-null   float64
#  6   Interest Expense                 4283 non-null   float64
#  7   Income Tax Expense               4325 non-null   float64
#  8   Net Income                       4340 non-null   float64
#  9   Gross Margin                     4431 non-null   float64
#  10  Profit Margin                    4158 non-null   float64
# ...

# %%
# Checking Null Values 
data.isnull().sum()
# Out:
# Revenue                             525
# Cost of Revenue                     679
# Gross Profit                        534
# R&D Expenses                        787
# SG&A Expense                        661
# Operating Expenses                  661
# Interest Expense                    677
# Income Tax Expense                  635
# Net Income                          620
# Gross Margin                        529
# Profit Margin                       802
# Free Cash Flow margin               840
# Consolidated Income                 620
# Short-term investments              721
# Receivables                         499
# Inventories                         694
# Total current assets                652
# Property, Plant & Equipment Net     644
# Long-term investments               702
# Total non-current assets           1536
# Payables                            642
# Short-term debt                     707
# Total current liabilities           650
# ...

# %%
# Filling Null Values
impute = SimpleImputer(strategy='mean')
dataimpute = impute.fit_transform(data)

# %%
df = pd.DataFrame(dataimpute , columns=data.columns)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4960 entries, 0 to 4959
# Data columns (total 50 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Revenue                          4960 non-null   float64
#  1   Cost of Revenue                  4960 non-null   float64
#  2   Gross Profit                     4960 non-null   float64
#  3   R&D Expenses                     4960 non-null   float64
#  4   SG&A Expense                     4960 non-null   float64
#  5   Operating Expenses               4960 non-null   float64
#  6   Interest Expense                 4960 non-null   float64
#  7   Income Tax Expense               4960 non-null   float64
#  8   Net Income                       4960 non-null   float64
#  9   Gross Margin                     4960 non-null   float64
#  10  Profit Margin                    4960 non-null   float64
# ...

# %% [markdown]
# EDA

# %%
plt.scatter(x = df['Revenue'] , y = df['Cost of Revenue'])
plt.show()

# %%
plt.figure(figsize=(30,30))
columns_to_plot = ['R&D Expenses' , 'SG&A Expense' , 'Operating Expenses' , 'Interest Expense']
sns.pairplot(df[columns_to_plot])
plt.show()
# Out:
# D:\Users\Jeewanshu Gaur\anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# D:\Users\Jeewanshu Gaur\anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# D:\Users\Jeewanshu Gaur\anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
df[columns_to_plot].plot(kind='line', subplots=True, layout=(3, 2), figsize=(10, 10), title=columns_to_plot)
plt.tight_layout()
plt.show()

# %%
plt.scatter(x = df['R&D Expenses'] , y = df['R&D Expense Growth'])
plt.show()

# %%
plt.figure(figsize = (100,100))
sns.heatmap(df.corr() , annot=True , cmap = 'viridis')
plt.show()

# %%
plt.scatter(x = df['Investments'] , y = df['Revenue'])
plt.show()

# %%
# Splitting dataset into training and testing
x = df.iloc[: , 0:49]
y = df.iloc[: , -1]
x_train , x_test , y_train , y_test = train_test_split(x , y , test_size=0.2 , random_state=42)

# %%
x_train
# Out:
#            Revenue  Cost of Revenue  Gross Profit  R&D Expenses  SG&A Expense  \
# 4449  5.484410e+08     3.328440e+08  2.155970e+08  7.380700e+07  9.467900e+07
# 1204  2.296807e+10     8.631984e+09  1.433609e+10  2.475693e+09  4.143521e+09
# 80    8.903150e+08     5.299040e+08  3.604110e+08  0.000000e+00  2.428910e+08
# 803   3.591200e+07     3.438000e+06  3.247400e+07  1.284400e+07  3.624900e+07
# 1769  1.431400e+10     8.306000e+09  6.008000e+09  0.000000e+00  2.412000e+09
# ...            ...              ...           ...           ...           ...
# 4426  4.301650e+08     1.274220e+08  3.027430e+08  1.152910e+08  2.935980e+08
# 466   9.982300e+07     5.798400e+07  4.183900e+07  0.000000e+00  0.000000e+00
# 3092  2.426670e+08     1.996170e+08  4.305000e+07  9.768000e+06  3.592400e+07
# 3772  9.078900e+07     0.000000e+00  9.078900e+07  0.000000e+00  5.132700e+07
# 860   3.337640e+08     1.166220e+08  2.171420e+08  3.166100e+07  1.843160e+08
#
# ...

# %%
y_train
# Out:
# 4449    0.0
# 1204    0.0
# 80      1.0
# 803     0.0
# 1769    0.0
#        ...
# 4426    1.0
# 466     0.0
# 3092    0.0
# 3772    0.0
# 860     1.0
# Name: Class, Length: 3968, dtype: float64

# %%
# Scaling the dataset
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
# Logistic Regression
LR = LogisticRegression()
LR.fit(x_train , y_train)
y_pred = LR.predict(x_test)
accuracy_score(y_test , y_pred)
# Out:
# 0.7096774193548387

# %%
# Decision Tree
DT = DecisionTreeClassifier(max_depth=5)
DT.fit(x_train , y_train)
y_pred1 = DT.predict(x_test)
accuracy_score(y_test , y_pred1)
# Out:
# 0.7157258064516129

# %%
# Random Forest
RF = RandomForestClassifier()
RF.fit(x_train , y_train)
y_pred2 = RF.predict(x_test)
accuracy_score(y_test , y_pred2)
# Out:
# 0.717741935483871

# %%
data = {
    'Revenue': 65058009000,
    'Cost of Revenue': 326380000000,
    'Gross Profit': 3242000000,
    'R&D Expenses': 0,
    'SG&A Expense': 19654000000,
    'Operating Expenses': 1864000000,
    'Interest Expense': 4650000000,
    'Income Tax Expense': 306300000,
    'Net Income': 153260000009,
    'Gross Margin': 0.49831,
    'Profit Margin': 0.2361,
    'Free Cash Flow margin': 0.144,
    'Consolidated Income': 15411000000,
    'Short-term investments': 19568000000,
    'Receivables': 45940010000,
    'Inventories': 46240000100,
    'Total current assets': 264941000000,
    'Property, Plant & Equipment Net': 19893000000,
    'Long-term investments': 0,
    'Total non-current assets': 93912000000,
    'Payables': 96320001000,
    'Short-term debt': 13554000000,
    'Total current liabilities': 3021000000,
    'Total debt': 3152000000,
    'Deferred revenue': 0,
    'Total liabilities': 6462800000,
    'Other comprehensive income': -1463200000,
    'Total shareholders equity': 5577800000,
    'Investments': 95680000004,
    'Depreciation & Amortization': 28240000000,
    'Capital Expenditure': -33484000000,
    'Acquisitions and disposals': -491000000,
    'Investment purchases and sales': -3381000000,
    'Issuance (repayment) of debt': 139900000,
    'Issuance (buybacks) of shares': -273100000,
    'Effect of forex changes on cash': -2900000,
    'Net Income per Share': 5.9923,
    'Shareholders Equity per Share': 21.80816,
    'Market Cap': 22300000000,
    'Enterprise Value': 2390000000,
    'Income Quality': 0.8321,
    'Invested Capital': 47333000000,
    'Average Payables': 9478500000,
    'Days Sales Outstanding': 25.7741,
    'Operating Income Growth': 0.0242,
    'Inventory Growth': -0.0195,
    'Asset Growth': -0.0529,
    'Debt Growth': 0.0325,
    'R&D Expense Growth': 0
}

newdf = pd.DataFrame([data])

# %%
LR.predict(newdf)
# Out:
# D:\Users\Jeewanshu Gaur\anaconda\Lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# array([1.])

# %%
DT.predict(newdf)
# Out:
# D:\Users\Jeewanshu Gaur\anaconda\Lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# array([0.])

# %%
RF.predict(newdf)
# Out:
# D:\Users\Jeewanshu Gaur\anaconda\Lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# array([0.])
